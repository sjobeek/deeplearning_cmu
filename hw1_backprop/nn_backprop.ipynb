# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import nn_backprop as nnbp

# %%
IMG_DIM = 28

# %% [markdown]
# # Problem 5

# %% [markdown]
# ### Load data, randomize order, then plot a few examples...

# %%
alldata_t = np.loadtxt('./data/digitstrain.txt', delimiter=',')

# %%
np.random.seed(42)
np.random.shuffle(alldata_t)

# %%
y_t = alldata_t[:,-1].astype(int)
print(y_t.size)
y_t[:100].reshape((10,10))  # Labels...
# Out:
# 3000
# array([[6, 3, 6, 0, 8, 3, 4, 7, 1, 8],
#        [7, 0, 2, 5, 9, 3, 3, 1, 9, 8],
#        [0, 0, 3, 6, 4, 9, 8, 4, 0, 4],
#        [3, 5, 2, 9, 0, 2, 7, 1, 0, 4],
#        [0, 0, 1, 2, 5, 5, 8, 0, 8, 5],
#        [3, 7, 0, 8, 0, 9, 4, 2, 8, 3],
#        [2, 2, 2, 0, 0, 3, 4, 4, 5, 1],
#        [5, 8, 9, 6, 0, 2, 7, 9, 7, 8],
#        [6, 6, 2, 6, 6, 0, 8, 4, 8, 9],
#        [1, 4, 8, 4, 5, 1, 8, 7, 0, 5]])

# %%
digits_t = alldata_t[:,:-1]
print(digits_t[0].size)
#nnbp.plot_vec(digits_t[0])
nnbp.plot_100(digits_t)
# Out:
# 784

# %% [markdown]
# ## a) Basic Generalization
